# %%
import pandas as pd

# %%
datos = pd.read_csv('spotify_top_charts_22.csv')

# %%
df = pd.DataFrame(datos)

# %%
datos.shape
# Out:
# (646, 17)

# %%
datos.size
# Out:
# 10982

# %%
datos.head(10)
# Out:
#                                     uri  \
# 0  spotify:track:02MWAaffLxlfxAUY7c5dvx
# 1  spotify:track:5PjdY0CKGZdEuoNab3yDmX
# 2  spotify:track:3IAfUEeaXRX9s9UdKOJrFI
# 3  spotify:track:1HhNoOuqm1a5MXYEgAFl8o
# 4  spotify:track:4fouWK6XVHhzl78KzQ1UjL
# 5  spotify:track:7rglLriMNBPAyuJOMGwi39
# 6  spotify:track:1ri9ZUkBJVFUdgwzCnfcYs
# 7  spotify:track:5Z9KJZvQzH6PFmb8SNkxuk
# 8  spotify:track:6mmPpaltUZK7xjNlBPQQ0p
# 9  spotify:track:50nfwKoDiSYg8zOCREWAm5
#
#                                       artist_names  \
# 0                                    Glass Animals
# 1                     The Kid LAROI, Justin Bieber
# 2                                           Anitta
# 3  Imagine Dragons, JID, Arcane, League of Legends
# 4                                            GAYLE
# 5                       Elton John, Dua Lipa, PNAU
# 6                                 Becky G, KAROL G
# 7                           Lil Nas X, Jack Harlow
# 8                 Rauw Alejandro, Chencho Corleone
# ...

# %%
datos.tail(20)
# Out:
#                                       uri  \
# 626  spotify:track:3XYRV7ZSHqIRDG87DKTtry
# 627  spotify:track:6krYS8KtmNAYyb5uTZiYW4
# 628  spotify:track:5XbA7TAqsD0fj0dGBrbb0D
# 629  spotify:track:6zzdyvVWjGrQBraSvuqJPY
# 630  spotify:track:759ndr57jb0URg4j9YSWml
# 631  spotify:track:6a4GH1gljLL7VvmO9u5O92
# 632  spotify:track:3vJcz8exedHCjQ9ed95NqU
# 633  spotify:track:1NlK2NtpuUazpziLhnJwEV
# 634  spotify:track:3XLbDUB5BX2WqL2qoAsvtb
# 635  spotify:track:6gPPoRYJwCsoB2VVdPJfmo
# 636  spotify:track:0boodYr1uIpSVmGSP65Fmk
# 637  spotify:track:2iCDO8ePNuCvMiMFc0FQdA
# 638  spotify:track:2ZGEjmwyeZ3rpEezkZwqOP
# 639  spotify:track:6M3PsepEj5gyJoIi7Xvr7u
# 640  spotify:track:0lJE8f0lx8mUSfMyxeYpiC
# 641  spotify:track:0So2sgVa8aJiARPl2P29u2
# 642  spotify:track:1TUuhV75FeOF6UObRsABo2
# 643  spotify:track:3GbQcjKWT7eVpUfzqwUjxv
# 644  spotify:track:7My9ca9QEIR8MvIOdIrTWA
# 645  spotify:track:4axSuOg3BqsowKjRpj59RU
#
#                               artist_names  \
# ...

# %%
datos [['artist_names','track_name']].tail(8)
# Out:
#                               artist_names  \
# 638                      Gunna, Young Thug
# 639                             The Weeknd
# 640                          TINI, L-Gante
# 641                                  SALES
# 642                          Morgan Wallen
# 643  Lil Nas X, YoungBoy Never Broke Again
# 644                     Eminem, Snoop Dogg
# 645                           Taylor Swift
#
#                                             track_name
# 638                             mop (feat. Young Thug)
# 639                    Take My Breath - Single Version
# 640                                                Bar
# 641                                 Pope Is a Rockstar
# 642                                  Don't Think Jesus
# 643  Late To Da Party (F*CK BET) (feat. YoungBoy Ne...
# 644             From The D 2 The LBC (with Snoop Dogg)
# 645  Carolina - From The Motion Picture “Where The ...

# %%
datos_filtrados = datos['artist_names']=='Taylor Swift'

# %%
datos[datos_filtrados]
# Out:
#                                       uri  artist_names  \
# 129  spotify:track:1u8c2t2Cy7UBoG4ArRcF5g  Taylor Swift
# 157  spotify:track:5enxwA8aAbwZbf5qCHORXi  Taylor Swift
# 247  spotify:track:3hUxzQpSfdDqwM3ZTFQY0K  Taylor Swift
# 265  spotify:track:1R0a2iXumgCiFb7HEZ7gUE  Taylor Swift
# 391  spotify:track:04S1pkp1VaIqjg8zZqknR5  Taylor Swift
# 521  spotify:track:4d1CG5ei1E2vGbvmgf5KKv  Taylor Swift
# 565  spotify:track:1Ov37jtRQ2YNAe8HzfczkL  Taylor Swift
# 645  spotify:track:4axSuOg3BqsowKjRpj59RU  Taylor Swift
#
#                                             track_name  peak_rank  \
# 129                                        Blank Space        130
# 157  All Too Well (10 Minute Version) (Taylor's Ver...          1
# 247                                             august         11
# 265                                     Don’t Blame Me         72
# 391                                          Enchanted         61
# ...
